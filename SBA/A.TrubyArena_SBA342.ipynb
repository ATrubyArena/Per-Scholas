# %%
import requests

url = "https://jsonmock.hackerrank.com/api/medical_records"

def get_all_records():
    records = []
    page = 1 
    while True:
        response = requests.get(f"{url}/?page={page}")
        if response.status_code == 200:
            data = response.json()  
            records.extend(data['data'])
            if data['page'] < data['total_pages']:
                page += 1 
            else:
                break
        
    return records

records = get_all_records()

for record in records:
    print(record)
# Out:
# {'id': 1, 'timestamp': 1565637002408, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 154, 'bloodPressureSystole': 91, 'pulse': 125, 'breathingRate': 32, 'bodyTemperature': 100}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 172}}
# {'id': 2, 'timestamp': 1562539731129, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 139, 'bloodPressureSystole': 81, 'pulse': 104, 'breathingRate': 20, 'bodyTemperature': 99.4}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 171}}
# {'id': 3, 'timestamp': 1563465027370, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 125, 'bloodPressureSystole': 76, 'pulse': 113, 'breathingRate': 22, 'bodyTemperature': 100.8}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 185}}
# {'id': 4, 'timestamp': 1561018581520, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 138, 'bloodPressureSystole': 80, 'pulse': 124, 'breathingRate': 22, 'bodyTemperature': 97}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 185}}
# {'id': 5, 'timestamp': 1557725281296, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 153, 'bloodPressureSystole': 99, 'pulse': 124, 'breathingRate': 34, 'bodyTemperature': 102.5}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 210}}
# {'id': 6, 'timestamp': 1568550058964, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 155, 'bloodPressureSystole': 90, 'pulse': 130, 'breathingRate': 29, 'bodyTemperature': 99.2}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 173}}
# {'id': 7, 'timestamp': 1564691138999, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 147, 'bloodPressureSystole': 100, 'pulse': 138, 'breathingRate': 25, 'bodyTemperature': 100}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 196}}
# {'id': 8, 'timestamp': 1562157191823, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 122, 'bloodPressureSystole': 77, 'pulse': 91, 'breathingRate': 20, 'bodyTemperature': 101.5}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 175}}
# {'id': 9, 'timestamp': 1548036340751, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 147, 'bloodPressureSystole': 96, 'pulse': 130, 'breathingRate': 28, 'bodyTemperature': 101}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 106}}
# {'id': 10, 'timestamp': 1562161672195, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 127, 'bloodPressureSystole': 78, 'pulse': 130, 'breathingRate': 22, 'bodyTemperature': 103.8}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 110}}
# {'id': 11, 'timestamp': 1563846626267, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 126, 'bloodPressureSystole': 75, 'pulse': 99, 'breathingRate': 22, 'bodyTemperature': 101.9}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 108}}
# {'id': 12, 'timestamp': 1563860299099, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 126, 'bloodPressureSystole': 78, 'pulse': 117, 'breathingRate': 23, 'bodyTemperature': 99.2}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 217}}
# {'id': 13, 'timestamp': 1551906996274, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 121, 'bloodPressureSystole': 80, 'pulse': 91, 'breathingRate': 18, 'bodyTemperature': 101.3}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 180}}
# {'id': 14, 'timestamp': 1563044698171, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 139, 'bloodPressureSystole': 84, 'pulse': 105, 'breathingRate': 23, 'bodyTemperature': 97.3}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 186}}
# {'id': 15, 'timestamp': 1551566179628, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 136, 'bloodPressureSystole': 88, 'pulse': 112, 'breathingRate': 25, 'bodyTemperature': 99.3}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 192}}
# {'id': 16, 'timestamp': 1568085122164, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 136, 'bloodPressureSystole': 85, 'pulse': 117, 'breathingRate': 29, 'bodyTemperature': 99.9}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 186}}
# {'id': 17, 'timestamp': 1547084560364, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 129, 'bloodPressureSystole': 79, 'pulse': 102, 'breathingRate': 16, 'bodyTemperature': 103.4}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 185}}
# {'id': 18, 'timestamp': 1560177927736, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 141, 'bloodPressureSystole': 96, 'pulse': 123, 'breathingRate': 29, 'bodyTemperature': 99}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 103}}
# {'id': 19, 'timestamp': 1557740937538, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 127, 'bloodPressureSystole': 76, 'pulse': 90, 'breathingRate': 19, 'bodyTemperature': 100.4}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 189}}
# {'id': 20, 'timestamp': 1549184918171, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 145, 'bloodPressureSystole': 94, 'pulse': 125, 'breathingRate': 25, 'bodyTemperature': 102.6}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 181}}
# {'id': 21, 'timestamp': 1560237165337, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 155, 'bloodPressureSystole': 94, 'pulse': 120, 'breathingRate': 33, 'bodyTemperature': 102.3}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 205}}
# {'id': 22, 'timestamp': 1563243111785, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 139, 'bloodPressureSystole': 82, 'pulse': 105, 'breathingRate': 28, 'bodyTemperature': 97.1}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 196}}
# {'id': 23, 'timestamp': 1551214310616, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 123, 'bloodPressureSystole': 79, 'pulse': 117, 'breathingRate': 16, 'bodyTemperature': 101.8}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 215}}
# {'id': 24, 'timestamp': 1563805161434, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 144, 'bloodPressureSystole': 92, 'pulse': 137, 'breathingRate': 34, 'bodyTemperature': 102.5}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 191}}
# {'id': 25, 'timestamp': 1551539005307, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 154, 'bloodPressureSystole': 90, 'pulse': 131, 'breathingRate': 22, 'bodyTemperature': 103}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 107}}
# {'id': 26, 'timestamp': 1564765981840, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 144, 'bloodPressureSystole': 90, 'pulse': 135, 'breathingRate': 28, 'bodyTemperature': 99.2}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 178}}
# {'id': 27, 'timestamp': 1556836728887, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 133, 'bloodPressureSystole': 84, 'pulse': 124, 'breathingRate': 26, 'bodyTemperature': 99.2}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 109}}
# {'id': 28, 'timestamp': 1550268297157, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 154, 'bloodPressureSystole': 99, 'pulse': 125, 'breathingRate': 33, 'bodyTemperature': 100.1}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 195}}
# {'id': 29, 'timestamp': 1551436887626, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 124, 'bloodPressureSystole': 80, 'pulse': 129, 'breathingRate': 21, 'bodyTemperature': 102.3}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 107}}
# {'id': 30, 'timestamp': 1549051080085, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 130, 'bloodPressureSystole': 82, 'pulse': 114, 'breathingRate': 23, 'bodyTemperature': 98.6}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 188}}
# {'id': 31, 'timestamp': 1555004832077, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 154, 'bloodPressureSystole': 90, 'pulse': 138, 'breathingRate': 26, 'bodyTemperature': 102.9}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 178}}
# {'id': 32, 'timestamp': 1554074088481, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 135, 'bloodPressureSystole': 82, 'pulse': 119, 'breathingRate': 29, 'bodyTemperature': 97.8}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 183}}
# {'id': 33, 'timestamp': 1552027463340, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 133, 'bloodPressureSystole': 83, 'pulse': 126, 'breathingRate': 19, 'bodyTemperature': 99.7}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 185}}
# {'id': 34, 'timestamp': 1553964012428, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 151, 'bloodPressureSystole': 95, 'pulse': 126, 'breathingRate': 29, 'bodyTemperature': 102.9}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 102}}
# {'id': 35, 'timestamp': 1560628606015, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 151, 'bloodPressureSystole': 98, 'pulse': 140, 'breathingRate': 27, 'bodyTemperature': 100.7}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 186}}
# {'id': 36, 'timestamp': 1548913424982, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 155, 'bloodPressureSystole': 96, 'pulse': 130, 'breathingRate': 24, 'bodyTemperature': 99.3}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 212}}
# {'id': 37, 'timestamp': 1546833849804, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 142, 'bloodPressureSystole': 92, 'pulse': 124, 'breathingRate': 27, 'bodyTemperature': 100.9}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 175}}
# {'id': 38, 'timestamp': 1566641257487, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 145, 'bloodPressureSystole': 97, 'pulse': 126, 'breathingRate': 24, 'bodyTemperature': 99.9}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 204}}
# {'id': 39, 'timestamp': 1561707512924, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 120, 'bloodPressureSystole': 78, 'pulse': 109, 'breathingRate': 19, 'bodyTemperature': 99.8}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 182}}
# {'id': 40, 'timestamp': 1555756519577, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 131, 'bloodPressureSystole': 84, 'pulse': 102, 'breathingRate': 28, 'bodyTemperature': 98.3}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 200}}
# {'id': 41, 'timestamp': 1546789224456, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 151, 'bloodPressureSystole': 96, 'pulse': 130, 'breathingRate': 26, 'bodyTemperature': 103}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 174}}
# {'id': 42, 'timestamp': 1551568255913, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 133, 'bloodPressureSystole': 86, 'pulse': 115, 'breathingRate': 26, 'bodyTemperature': 97.7}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 110}}
# {'id': 43, 'timestamp': 1552730470697, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 125, 'bloodPressureSystole': 76, 'pulse': 94, 'breathingRate': 17, 'bodyTemperature': 101}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 177}}
# {'id': 44, 'timestamp': 1569042212278, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 133, 'bloodPressureSystole': 84, 'pulse': 106, 'breathingRate': 27, 'bodyTemperature': 99.4}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 177}}
# {'id': 45, 'timestamp': 1548464457450, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 124, 'bloodPressureSystole': 77, 'pulse': 82, 'breathingRate': 20, 'bodyTemperature': 100.6}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 191}}
# {'id': 46, 'timestamp': 1549095347187, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 133, 'bloodPressureSystole': 83, 'pulse': 123, 'breathingRate': 20, 'bodyTemperature': 97.3}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 189}}
# {'id': 47, 'timestamp': 1568317109556, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 139, 'bloodPressureSystole': 83, 'pulse': 124, 'breathingRate': 26, 'bodyTemperature': 99.7}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 104}}
# {'id': 48, 'timestamp': 1562368169611, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 154, 'bloodPressureSystole': 94, 'pulse': 129, 'breathingRate': 26, 'bodyTemperature': 101.4}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 177}}
# {'id': 49, 'timestamp': 1569150506368, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 124, 'bloodPressureSystole': 76, 'pulse': 89, 'breathingRate': 22, 'bodyTemperature': 102.6}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 105}}
# {'id': 50, 'timestamp': 1557348400373, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 120, 'bloodPressureSystole': 77, 'pulse': 106, 'breathingRate': 16, 'bodyTemperature': 100.8}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 191}}
# {'id': 51, 'timestamp': 1556636816995, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 144, 'bloodPressureSystole': 99, 'pulse': 132, 'breathingRate': 34, 'bodyTemperature': 99.2}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 102}}
# {'id': 52, 'timestamp': 1567986262336, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 142, 'bloodPressureSystole': 100, 'pulse': 139, 'breathingRate': 34, 'bodyTemperature': 100.1}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 192}}
# {'id': 53, 'timestamp': 1555540608366, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 128, 'bloodPressureSystole': 78, 'pulse': 103, 'breathingRate': 17, 'bodyTemperature': 103.8}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 186}}
# {'id': 54, 'timestamp': 1550526546202, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 125, 'bloodPressureSystole': 76, 'pulse': 125, 'breathingRate': 16, 'bodyTemperature': 102}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 190}}
# {'id': 55, 'timestamp': 1555078372353, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 126, 'bloodPressureSystole': 78, 'pulse': 110, 'breathingRate': 21, 'bodyTemperature': 99.8}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 182}}
# {'id': 56, 'timestamp': 1556411602393, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 150, 'bloodPressureSystole': 90, 'pulse': 122, 'breathingRate': 27, 'bodyTemperature': 102.8}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 109}}
# {'id': 57, 'timestamp': 1567075681694, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 153, 'bloodPressureSystole': 98, 'pulse': 136, 'breathingRate': 27, 'bodyTemperature': 102.4}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 216}}
# {'id': 58, 'timestamp': 1566716431319, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 127, 'bloodPressureSystole': 80, 'pulse': 122, 'breathingRate': 20, 'bodyTemperature': 103.9}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 100}}
# {'id': 59, 'timestamp': 1550811320467, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 127, 'bloodPressureSystole': 80, 'pulse': 122, 'breathingRate': 23, 'bodyTemperature': 103.7}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 190}}
# {'id': 60, 'timestamp': 1550168990969, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 121, 'bloodPressureSystole': 79, 'pulse': 80, 'breathingRate': 17, 'bodyTemperature': 99.1}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 172}}
# {'id': 61, 'timestamp': 1556154158487, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 138, 'bloodPressureSystole': 85, 'pulse': 105, 'breathingRate': 24, 'bodyTemperature': 97.9}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 171}}
# {'id': 62, 'timestamp': 1553526236105, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 125, 'bloodPressureSystole': 80, 'pulse': 125, 'breathingRate': 18, 'bodyTemperature': 102.4}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 213}}
# {'id': 63, 'timestamp': 1553432579843, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 148, 'bloodPressureSystole': 93, 'pulse': 134, 'breathingRate': 34, 'bodyTemperature': 101.2}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 104}}
# {'id': 64, 'timestamp': 1561565310725, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 151, 'bloodPressureSystole': 94, 'pulse': 126, 'breathingRate': 23, 'bodyTemperature': 99.5}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 204}}
# {'id': 65, 'timestamp': 1546578199172, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 121, 'bloodPressureSystole': 78, 'pulse': 119, 'breathingRate': 17, 'bodyTemperature': 104}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 176}}
# {'id': 66, 'timestamp': 1548547587713, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 123, 'bloodPressureSystole': 79, 'pulse': 100, 'breathingRate': 23, 'bodyTemperature': 104}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 201}}
# {'id': 67, 'timestamp': 1565124807315, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 135, 'bloodPressureSystole': 83, 'pulse': 127, 'breathingRate': 27, 'bodyTemperature': 97.3}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 99}}
# {'id': 68, 'timestamp': 1551328147115, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 137, 'bloodPressureSystole': 80, 'pulse': 110, 'breathingRate': 27, 'bodyTemperature': 99.4}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 105}}
# {'id': 69, 'timestamp': 1555912747970, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 125, 'bloodPressureSystole': 76, 'pulse': 107, 'breathingRate': 18, 'bodyTemperature': 102.9}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 174}}
# {'id': 70, 'timestamp': 1563340551043, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 146, 'bloodPressureSystole': 100, 'pulse': 122, 'breathingRate': 34, 'bodyTemperature': 100.1}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 108}}
# {'id': 71, 'timestamp': 1559734437066, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 140, 'bloodPressureSystole': 99, 'pulse': 136, 'breathingRate': 28, 'bodyTemperature': 99.8}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 192}}
# {'id': 72, 'timestamp': 1553498179149, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 134, 'bloodPressureSystole': 87, 'pulse': 104, 'breathingRate': 28, 'bodyTemperature': 98.8}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 176}}
# {'id': 73, 'timestamp': 1556167565792, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 141, 'bloodPressureSystole': 91, 'pulse': 126, 'breathingRate': 22, 'bodyTemperature': 100.9}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 210}}
# {'id': 74, 'timestamp': 1555518786264, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 139, 'bloodPressureSystole': 83, 'pulse': 114, 'breathingRate': 18, 'bodyTemperature': 97}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 195}}
# {'id': 75, 'timestamp': 1568875528406, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 153, 'bloodPressureSystole': 92, 'pulse': 131, 'breathingRate': 28, 'bodyTemperature': 99.1}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 101}}
# {'id': 76, 'timestamp': 1550258129098, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 153, 'bloodPressureSystole': 92, 'pulse': 129, 'breathingRate': 27, 'bodyTemperature': 102}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 175}}
# {'id': 77, 'timestamp': 1555075791784, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 138, 'bloodPressureSystole': 81, 'pulse': 125, 'breathingRate': 25, 'bodyTemperature': 100}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 182}}
# {'id': 78, 'timestamp': 1562627963327, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 151, 'bloodPressureSystole': 100, 'pulse': 130, 'breathingRate': 33, 'bodyTemperature': 100}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 181}}
# {'id': 79, 'timestamp': 1558943627866, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 123, 'bloodPressureSystole': 78, 'pulse': 80, 'breathingRate': 21, 'bodyTemperature': 100.8}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 215}}
# {'id': 80, 'timestamp': 1555409302000, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 121, 'bloodPressureSystole': 79, 'pulse': 102, 'breathingRate': 24, 'bodyTemperature': 99.3}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 108}}
# {'id': 81, 'timestamp': 1567973810992, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 127, 'bloodPressureSystole': 80, 'pulse': 81, 'breathingRate': 19, 'bodyTemperature': 99.2}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 195}}
# {'id': 82, 'timestamp': 1549891890194, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 147, 'bloodPressureSystole': 97, 'pulse': 127, 'breathingRate': 28, 'bodyTemperature': 99.5}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 194}}
# {'id': 83, 'timestamp': 1548314182815, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 121, 'bloodPressureSystole': 80, 'pulse': 91, 'breathingRate': 21, 'bodyTemperature': 103.5}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 211}}
# {'id': 84, 'timestamp': 1561566531731, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 152, 'bloodPressureSystole': 96, 'pulse': 130, 'breathingRate': 25, 'bodyTemperature': 103}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 193}}
# {'id': 85, 'timestamp': 1546535157430, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 146, 'bloodPressureSystole': 90, 'pulse': 128, 'breathingRate': 27, 'bodyTemperature': 102.2}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 172}}
# {'id': 86, 'timestamp': 1556220713993, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 121, 'bloodPressureSystole': 79, 'pulse': 130, 'breathingRate': 20, 'bodyTemperature': 100.2}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 4, 'userName': 'Francesco De Mello', 'userDob': '02-05-1994', 'meta': {'height': 183, 'weight': 209}}
# {'id': 87, 'timestamp': 1566675866297, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 131, 'bloodPressureSystole': 84, 'pulse': 100, 'breathingRate': 26, 'bodyTemperature': 98.9}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 179}}
# {'id': 88, 'timestamp': 1557308487952, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 121, 'bloodPressureSystole': 79, 'pulse': 126, 'breathingRate': 16, 'bodyTemperature': 102.7}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 175}}
# {'id': 89, 'timestamp': 1559893795048, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 138, 'bloodPressureSystole': 85, 'pulse': 113, 'breathingRate': 28, 'bodyTemperature': 97.8}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 184}}
# {'id': 90, 'timestamp': 1567995285165, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 123, 'bloodPressureSystole': 76, 'pulse': 125, 'breathingRate': 16, 'bodyTemperature': 103.8}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 177}}
# {'id': 91, 'timestamp': 1553090580792, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 120, 'bloodPressureSystole': 80, 'pulse': 82, 'breathingRate': 21, 'bodyTemperature': 100.3}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 109}}
# {'id': 92, 'timestamp': 1564291090683, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 151, 'bloodPressureSystole': 93, 'pulse': 136, 'breathingRate': 27, 'bodyTemperature': 101.7}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 183}}
# {'id': 93, 'timestamp': 1552824309852, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 138, 'bloodPressureSystole': 81, 'pulse': 129, 'breathingRate': 19, 'bodyTemperature': 98.6}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 3, 'userName': 'Helena Fernandez', 'userDob': '23-12-1987', 'meta': {'height': 157, 'weight': 100}}
# {'id': 94, 'timestamp': 1556172419659, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 135, 'bloodPressureSystole': 81, 'pulse': 114, 'breathingRate': 24, 'bodyTemperature': 97.1}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 178}}
# {'id': 95, 'timestamp': 1561993769914, 'diagnosis': {'id': 4, 'name': 'Pleurisy', 'severity': 3}, 'vitals': {'bloodPressureDiastole': 133, 'bloodPressureSystole': 89, 'pulse': 112, 'breathingRate': 30, 'bodyTemperature': 99.6}, 'doctor': {'id': 3, 'name': 'Dr Pilar Cristancho'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 181}}
# {'id': 96, 'timestamp': 1550084268468, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 143, 'bloodPressureSystole': 95, 'pulse': 123, 'breathingRate': 34, 'bodyTemperature': 101}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 177}}
# {'id': 97, 'timestamp': 1548756027237, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 121, 'bloodPressureSystole': 80, 'pulse': 118, 'breathingRate': 17, 'bodyTemperature': 99.5}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 179}}
# {'id': 98, 'timestamp': 1568922902985, 'diagnosis': {'id': 3, 'name': 'Pulmonary embolism', 'severity': 4}, 'vitals': {'bloodPressureDiastole': 140, 'bloodPressureSystole': 93, 'pulse': 140, 'breathingRate': 31, 'bodyTemperature': 102}, 'doctor': {'id': 2, 'name': 'Dr Arnold Bullock'}, 'userId': 1, 'userName': 'John Oliver', 'userDob': '02-01-1986', 'meta': {'height': 168, 'weight': 189}}
# {'id': 99, 'timestamp': 1551939212985, 'diagnosis': {'id': 2, 'name': 'Common Cold', 'severity': 1}, 'vitals': {'bloodPressureDiastole': 126, 'bloodPressureSystole': 75, 'pulse': 128, 'breathingRate': 21, 'bodyTemperature': 103.3}, 'doctor': {'id': 4, 'name': 'Dr Allysa Ellis'}, 'userId': 2, 'userName': 'Bob Martin', 'userDob': '14-09-1989', 'meta': {'height': 174, 'weight': 183}}

# %%
import requests

def bodyTemperature(doctorName, diagnosisId):
    """
    Write your code here.


    Function to filter medical records based on doctor's name and diagnosis ID
    and return the integer parts of the minimum and maximum body temperatures found in  the filtered records.


    Args:
        doctorName (str): The name of the doctor.
        diagnosisId (int): The ID of the diagnosis.


    Raises:
        Exception: If there is an issue with the HTTP request or JSON parsing.
       
    Returns:
        list: A list containing two integers, representing the integer parts of the minimum and maximum body temperatures.
              Returns [None, None] if no matching records are found.
    """

    

    try:
        url = "https://jsonmock.hackerrank.com/api/medical_records"
        page = 1
        temperatures = []

        response = requests.get(f"{url}?page={page}") #Finding out how many pages there are
        if response.status_code != 200: #If response code isnt successful (200) return none values
            return [None, None]

        data = response.json()
        total_pages = data.get("total_pages", 0) #Getting the total pages

        while page <= total_pages:   #If the page number is less than or equal the total amount of pages, continue
            page_url = f"{url}?page={page}"
            response = requests.get(page_url)
            json_data = response.json()
            records = json_data.get("data", [])

            for record in records: #Getting the doctor, diagnosis and vitals from record
                doctor = record.get("doctor", {})
                diagnosis = record.get("diagnosis", {})
                vitals = record.get("vitals", {})

                if doctor.get("name") == doctorName and diagnosis.get("id") == diagnosisId: #If doctor name and diagnosis id both exist then get vitals
                    temp = vitals.get("bodyTemperature")
                    if type(temp) in (int, float):
                        temperatures.append(int(temp))#Getting the temperature as a whole number and appending the emply list named "temperatures"

            page += 1

        if not temperatures: #Returning None if doctor name or diagnosis ID doesnt exist
            return [None, None]

        return [min(temperatures), max(temperatures)] #Returning min and max tempuratures back to the function

    except requests.exceptions.HTTPError as err:
        print(f"An error occurred: {err}")
        return [None, None]


doctor_name = "Dr Allysa Ellis"
diagnosis_id = 4
result = bodyTemperature(doctor_name, diagnosis_id)
print("Minimum Body Temperature:", result[0])
print("Maximum Body Temperature:", result[1])
# Out:
# Minimum Body Temperature: 97
# Maximum Body Temperature: 99
